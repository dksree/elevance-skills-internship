# %% [markdown]
# <a href="https://colab.research.google.com/github/dksree/elevance-skills-internship/blob/main/task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.graph_objects as go
from datetime import datetime
import pytz

# %%
df = pd.read_csv("google_play_store_dataset.csv")

df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size  Type Price Content Rating                     Genres  \
# 0     159   19M  Free     0       Everyone               Art & Design
# 1     967   14M  Free     0       Everyone  Art & Design;Pretend Play
# 2   87510  8.7M  Free     0       Everyone               Art & Design
# 3  215644   25M  Free     0           Teen               Art & Design
# 4     967  2.8M  Free     0       Everyone    Art & Design;Creativity
#
#        Last Updated         Current Ver   Android Ver Country
# ...

# %%
df['Reviews'] = pd.to_numeric(df['Reviews'], errors='coerce')

# %%
df['Price'] = df['Price'].astype(str).str.replace('$','')
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')

df['Revenue'] = df['Price'] * df['Reviews']

# %%
df['Size'] = df['Size'].str.replace('M','')
df['Size'] = pd.to_numeric(df['Size'], errors='coerce')

# %%
df['Android Ver'] = df['Android Ver'].str.extract('(\d+\.\d+)')
df['Android Ver'] = pd.to_numeric(df['Android Ver'], errors='coerce')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_790/4003742101.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df['Android Ver'] = df['Android Ver'].str.extract('(\d+\.\d+)')

# %%
df_filtered = df[
    (df['Reviews'] > 10000) &
    (df['Revenue'] > 10000) &
    (df['Android Ver'] > 4.0) &
    (df['Size'] > 15) &
    (df['Content Rating'] == "Everyone") &
    (df['App'].str.len() <= 30)
]

# %%
top_categories = df_filtered.groupby('Category')['Reviews'].sum().nlargest(3).index

df_top = df_filtered[df_filtered['Category'].isin(top_categories)]

# %%
summary = df_top.groupby('Type').agg({
    'Reviews':'mean',
    'Revenue':'mean'
}).reset_index()

summary
# Out:
#    Type   Reviews      Revenue
# 0  Paid  68374.25  195857.3825

# %%
fig = go.Figure()

fig.add_bar(
    x=summary['Type'],
    y=summary['Reviews'],
    name="Average Installs"
)

fig.add_scatter(
    x=summary['Type'],
    y=summary['Revenue'],
    name="Average Revenue",
    yaxis="y2",
    mode="lines+markers"
)

fig.update_layout(
    title="Average Installs vs Revenue (Free vs Paid Apps)",
    yaxis=dict(title="Average Installs"),
    yaxis2=dict(title="Average Revenue", overlaying='y', side='right')
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
ist = pytz.timezone('Asia/Kolkata')
current_time = datetime.now(ist)

if 13 <= current_time.hour < 14:
    fig.show()
else:
    print("Graph only visible between 1 PM and 2 PM IST")
# Out:
# Graph only visible between 1 PM and 2 PM IST
